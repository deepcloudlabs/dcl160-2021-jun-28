# %%
# string (str): i) character array (iterable -> for loop), len() ii) immutable

# %%
fullname = "jack shephard"

# %%
fullname = 'jack shephard'

# %%
fullname = "jack's house"

# %%
fullname[0]
# Out:
# 'j'

# %%
fullname[-1]
# Out:
# 'e'

# %%
len(fullname)
# Out:
# 12

# %%
try:
  fullname[12]
except IndexError:
  print("String index is out of the range")
# Out:
# String index is out of the range

# %%
fullname[-12]
# Out:
# 'j'

# %%
try:
  fullname[-13]
except IndexError:
  print("String index is out of the range")
# Out:
# String index is out of the range

# %%
fullname="jack shephard"

# %%
fullname[0]='J'

# %%
for c in fullname:
  print(c)

# %%
jsonEmployee="""{ 
   x: 1,
   y: 100,
   radius: 200
}"""

# %%
jsonCircle="{\n\tx: 1,\n\ty: 200,\n\tradius: 200\n}"

# %%
print(jsonCircle)

# %%
s = "\u20ba"

# %%
s

# %%
len(s)

# %%
fullname="jack bauer"

# %%
len(fullname)

# %%
fullname[0]

# %%
fullname[-1]

# %%
fullname[2:4]

# %%
fullname[:4]

# %%
fullname[5:]

# %%
fullname="jack bauer"
fullname[1:8:2]

# %%
fullname[::-1]

# %%
numbers = [4,8,15,16,23,42]

# %%
numbers[:4]

# %%
numbers[4:]

# %%
numbers[::-1]

# %%
sayilar = numbers

# %%
sayilar

# %%
numbers.append(58)

# %%
numbers

# %%
sayilar

# %%
sayilar.append(72)

# %%
sayilar

# %%
numbers

# %%
sayilar = list(numbers) # cloning the list

# %%
sayilar

# %%
numbers

# %%
sayilar.append(84)

# %%
numbers.append(94)

# %%
sayilar

# %%
numbers

# %%
sayilar = numbers[:] # cloning the list

# %%
sayilar

# %%
numbers

# %%
sayilar.append(108)

# %%
numbers

# %%
sayilar

# %%
sayilar = numbers[::-1]

# %%
sayilar

# %%
numbers

# %%
fullname="kate austen"

# %%
adsoyad=list(fullname)

# %%
adsoyad

# %%
adsoyad[0]='K'

# %%
adsoyad

# %%
adsoyad[5]='A'

# %%
adsoyad

# %%
str(adsoyad)

# %%
str(1)

# %%
str(2+5j)

# %%
s = str(3.1415)

# %%
type(s)

# %%
int(float(s))

# %%
try:
  x=float('pi')
except ValueError:  
  print("Error: cannot convert!")

# %%
fullname="kate austen" # immutable: i) thread-safe 
                       #           ii) functional programming: pure/high-order function -> does have side effect
                                                      # high memory consumption 
                                                      # *** generator function ***     
                       #           iii) object pooling -> immutable

# %%
upperCasedFullname = fullname.upper()

# %%
fullname

# %%
template = """<html>
<head>
  <title>Welcoming the registered user</title>
</head>
<body>
Hello {1:s}, {0:s}! 
Creating the following email account {0:s}.{1:s}@{2:s}.
</body>
</html>
"""

# %%
message = template.format("jack","shephard","example.com")

# %%
print(message)

# %%
"jack shephard" == "jack shephard"

# %%
"Jack shephard" != "jack shephard"

# %%
"a" < "b"

# %%
words="to be or not to be that is the question"

# %%
words.count("to")

# %%
words.count("to", 6)

# %%
words.count("to", 6,12)

# %%
words.index("to")

# %%
words.index("to",2)

# %%
try:
  words.index("to",15)
except ValueError:
  print("Cannot find 'to' after 15!")

# %%
start=0
searchStr='t'
while words.count(searchStr,start) > 0:
  i=words.index(searchStr,start) # safe
  print(f"Found at {i}")
  start=i+len(searchStr)

# %%
words.find("this")

# %%
"those" in words

# %%
words.find("those") > -1

# %%
words.replace("to","2")

# %%
words

# %%
input_str= "\t\t      \n\n    This is a sample input        \t\t\t\t  \n\n\n"

# %%
len(input_str)

# %%
# white space: \t \n \r space

# %%
input_str.strip()

# %%
input_str.lstrip()

# %%
input_str.rstrip()

# %%
line="11111111110,     jack shephard, tr8612341234123456,   100000, 1956"

# %%
identity,fullname,iban,salary,birthYear = line.split(",")

# %%
identity

# %%
fullname.strip()

# %%
iban.strip()

# %%
float(salary.strip())

# %%
int(birthYear.strip())

# %%
line="\t\t\n\n\n\n     test data\t\t     \n\n\n\t\t"
line.replace("\t","")

# %%
line="11111111110,     jack shephard, tr8612341234123456,   100000, 1956"

# %%
line.split(",")

# %%
values=[]
for value in line.split(","):
  values.append(value.strip())

# %%
values

# %%
list(map( lambda s : s.strip() , line.split(",")))

# %%
lineList = list(map( str.strip , line.split(","))) # functional thinking, csv -> list

# %%
numbers=[4,8,15,16,23,42]

# %%
str(numbers)[1:-1]

# %%
print("\t".join(lineList)) # list -> csv

# %%
another_line="11111111110	jack shephard	tr8612341234123456	100000	1956"

# %%
another_line.split("\t")
# Out:
# ['11111111110', 'jack shephard', 'tr8612341234123456', '100000', '1956']

# %%
"108".isdigit()
# Out:
# True

# %%
"lost108".isalnum()
# Out:
# True

# %%
"108a".isdecimal()
# Out:
# False

# %%
"\t  \n   \t".isspace()

# %%
"Jack Bauer".istitle()

# %%
"jack bauer".istitle()
