# %%
x=42

# %%
type(x)
# Out:
# int

# %%
x=3.141516

# %%
type(x)
# Out:
# float

# %%
x=1+1==2

# %%
type(x)
# Out:
# bool

# %%
x="kate austen"

# %%
type(x)
# Out:
# str

# %%
x=2+4j

# %%
type(x)
# Out:
# complex

# %%
x=complex(2,4)

# %%
type(x)
# Out:
# complex

# %%
x=False

# %%
type(x)
# Out:
# bool

# %%
x=None

# %%
type(x)
# Out:
# NoneType

# %%
x = 42 / 2

# %%
type(x)
# Out:
# float

# %%
x = 42 // 4

# %%
type(x)
# Out:
# int

# %%
x
# Out:
# 10

# %%
x = 0 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-28-b1e091682935> in <module>()
# ----> 1 x = 0 / 0
#
# ZeroDivisionError: division by zero

# %%
w = (0.1 + 0.2) + 0.3 == 0.1 + (0.2 + 0.3)

# %%
w
# Out:
# False

# %%
w = 100 * 4.35

# %%
w
# Out:
# 434.99999999999994

# %%
w = 2.0 - 1.1

# %%
w
# Out:
# 0.8999999999999999

# %%
# CPU (4 Core->8), GPU (Graphical Processing Unit, 1024-2048-4096), TPU (Tensor Processor Unit)
# IEEE-756 v5

# %%
i = 2
j = 2 ** 1000000

# %%
j
# Out:
# ...

# %%
type(j)
# Out:
# int

# %%
x = float('nan') # '-inf', 'inf', 'nan'

# %%
type(x)
# Out:
# float

# %%
x
# Out:
# nan

# %%
x = 2 * x + 4

# %%
x
# Out:
# nan

# %%
x == float("nan")
# Out:
# False

# %%
x
# Out:
# nan

# %%
x == x
# Out:
# False

# %%
def is_not_nan(u):
  return u == u

# %%
is_not_nan(x)
# Out:
# False

# %%
from mpmath import *

# %%
mp.dps=100
mp.pretty = True

# %%
4 * atan(1)
# Out:
# 3....

# %%
limit(lambda n: (1+1/n)**n , inf)
# Out:
# 2.718281828459045235360287471352662497757247093699959574966967627724076630353547594571382178525166427

# %%
fullname="KaTe AuSTeN" # string -> immutable -> functional programming

# %%
type(fullname)
# Out:
# str

# %%
fullname.title()
# Out:
# 'Kate Austen'

# %%
fullname
# Out:
# 'KaTe AuSTeN'

# %%
x=b"\xf0\x9d\x84\x9e"

# %%
len(fullname)
# Out:
# 11

# %%
len(x)
# Out:
# 4

# %%
clef = x.decode("utf-8")

# %%
clef
# Out:
# '𝄞'

# %%
len(clef)
# Out:
# 1

# %%
tl="₺"

# %%
tl.encode("utf-8")
# Out:
# b'\xe2\x82\xba'

# %%
len(tl)
# Out:
# 1

# %%
btl=tl.encode("utf-8")

# %%
len(btl)
# Out:
# 3

# %%
type(btl)
# Out:
# bytes

# %%
s = btl.decode("utf-8")

# %%
type(s)
# Out:
# str

# %%
print(s)
# Out:
# ₺

# %%
x=42

# %%
type(x)
# Out:
# int

# %%
print(x)
# Out:
# 42

# %%
str(x)
# Out:
# '42'

# %%
print(str(x))
# Out:
# 42

# %%
print("this","is","the","line")
# Out:
# this is the line

# %%
print("\\first name: \"%-8s\"\tlast name: \"%12s\"\tsalary: %-8.0f, age: %d\n" % ("jack", "bauer", 123.789,58))
# Out:
# \first name: "jack    "	last name: "       bauer"	salary: 124     , age: 58

# %%
print(r"\t\n\"\"")
# Out:
# \t\n\"\"

# %%
i = 42
j = 108
print("%d:%d" % (i,j))
# Out:
# 42:108

# %%
print(f"{i}:{j}")
# Out:
# 42:108

# %%
lines="the first line.\nthe second line.\nthe third line.\nthe forth line."

# %%
print(lines)
# Out:
# the first line.
# the second line.
# the third line.
# the forth line.

# %%
multi_line="""the first line.
the second line.
the third line.
the forth line.
"""

# %%
print(multi_line)
# Out:
# the first line.
# the second line.
# the third line.
# the forth line.

# %%
multi_line
# Out:
# 'the first line.\nthe second line.\nthe third line.\nthe forth line.\n'

# %%
from math import *

# %%
x = 100_000

# %%
x = 1e-5 # scientific notation

# %%
expm1(1e-8) # 1 / 100_000
# Out:
# 1.0000000050000001e-08

# %%
log10(10_000)
# Out:
# 4.0

# %%
sqrt(2.2)
# Out:
# 1.4832396974191326

# %%
4 * atan(1)
# Out:
# 3.141592653589793

# %%
# math   -> fpu -> IEE-754, lookup -> fast - optimization -> ALU
# mpmath -> you can control arithmetic precision using mp.pds=100 independent of cpu/fpu, iterative! -> numeric analysis techniques -> slow
