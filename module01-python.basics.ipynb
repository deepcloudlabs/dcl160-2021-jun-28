# %%
x=42

# %%
type(x)
# Out:
# int

# %%
x=3.141516

# %%
type(x)
# Out:
# float

# %%
x=1+1==2

# %%
type(x)
# Out:
# bool

# %%
x="kate austen"

# %%
type(x)
# Out:
# str

# %%
x=2+4j

# %%
type(x)
# Out:
# complex

# %%
x=complex(2,4)

# %%
type(x)
# Out:
# complex

# %%
x=False

# %%
type(x)
# Out:
# bool

# %%
x=None

# %%
type(x)
# Out:
# NoneType

# %%
x = 42 / 2

# %%
type(x)
# Out:
# float

# %%
x = 42 // 4

# %%
type(x)
# Out:
# int

# %%
x
# Out:
# 10

# %%
try:
  x = 0/0
except ZeroDivisionError:
  x = nan
print(x)
# Out:
# nan

# %%
try:
  x = 1/0
except ZeroDivisionError:
  x = inf
print(x)
# Out:
# +inf

# %%
try:
  x = -1/0
except ZeroDivisionError:
  x = -inf
print(x)
# Out:
# -inf

# %%
w = (0.1 + 0.2) + 0.3 == 0.1 + (0.2 + 0.3)

# %%
w

# %%
w = 100 * 4.35

# %%
w

# %%
w = 2.0 - 1.1

# %%
w

# %%
# CPU (4 Core->8), GPU (Graphical Processing Unit, 1024-2048-4096), TPU (Tensor Processor Unit)
# IEEE-756 v5

# %%
i = 2
j = 2 ** 1000000

# %%
j

# %%
type(j)

# %%
x = float('nan') # '-inf', 'inf', 'nan'

# %%
type(x)

# %%
x

# %%
x = 2 * x + 4

# %%
x

# %%
x == float("nan")

# %%
x

# %%
x == x

# %%
def is_nan(u):
  return not u == u

# %%
is_nan(x)

# %%
import math

# %%
math.isnan(x)

# %%
math.isinf(x)

# %%
math.isfinite(x)

# %%
from mpmath import *

# %%
mp.dps=30
mp.pretty = True

# %%
4 * atan(1)

# %%
limit(lambda n: (1+1/n)**n , inf)

# %%
fullname="KaTe AuSTeN" # string -> immutable -> functional programming

# %%
type(fullname)

# %%
fullname.title()

# %%
fullname

# %%
x=b"\xf0\x9d\x84\x9e"

# %%
len(fullname)

# %%
len(x)

# %%
clef = x.decode("utf-8")

# %%
clef

# %%
len(clef)

# %%
tl="₺"

# %%
tl.encode("utf-8")

# %%
len(tl)

# %%
btl=tl.encode("utf-8")

# %%
len(btl)

# %%
type(btl)

# %%
s = btl.decode("utf-8")

# %%
type(s)

# %%
print(s)

# %%
x=42

# %%
type(x)

# %%
print(x)

# %%
str(x)

# %%
print(str(x))

# %%
print("this","is","the","line")

# %%
print("\\first name: \"%-8s\"\tlast name: \"%12s\"\tsalary: %-8.0f, age: %d\n" % ("jack", "bauer", 123.789,58))

# %%
print(r"\t\n\"\"")

# %%
i = 42
j = 108
print("%d:%d" % (i,j))

# %%
print(f"{i}:{j}")

# %%
lines="the first line.\nthe second line.\nthe third line.\nthe forth line."

# %%
print(lines)

# %%
multi_line="""the first line.
the second line.
the third line.
the forth line.
"""

# %%
print(multi_line)

# %%
multi_line

# %%
from math import *

# %%
x = 100_000

# %%
x = 1e-5 # scientific notation

# %%
expm1(1e-8) # 1 / 100_000

# %%
log10(10_000)

# %%
sqrt(2.2)

# %%
4 * atan(1)

# %%
# math   -> fpu -> IEE-754, lookup -> fast - optimization -> ALU
# mpmath -> you can control arithmetic precision using mp.pds=100 independent of cpu/fpu, iterative! -> numeric analysis techniques -> slow
